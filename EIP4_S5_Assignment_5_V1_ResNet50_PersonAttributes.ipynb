# %% [markdown]
# <a href="https://colab.research.google.com/github/anilbhatt1/CNN-EIP4-S5/blob/master/EIP4_S5_Assignment_5_V1_ResNet50_PersonAttributes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.resnet50 import ResNet50
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head(2)
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
#
# [2 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head(2).T
# Out:
#                                                   0              1
# image_path                            resized/1.jpg  resized/2.jpg
# gender_female                                     0              1
# gender_male                                       1              0
# imagequality_Average                              1              1
# imagequality_Bad                                  0              0
# imagequality_Good                                 0              0
# age_15-25                                         0              0
# age_25-35                                         0              0
# age_35-45                                         1              1
# age_45-55                                         0              0
# age_55+                                           0              0
# weight_normal-healthy                             1              0
# weight_over-weight                                0              1
# weight_slightly-overweight                        0              0
# weight_underweight                                0              0
# carryingbag_Daily/Office/Work Bag                 0              0
# carryingbag_Grocery/Home/Plastic Bag              1              0
# carryingbag_None                                  0              1
# footwear_CantSee                                  0              0
# footwear_Fancy                                    0              0
# footwear_Normal                                   1              1
# emotion_Angry/Serious                             0              1
# emotion_Happy                                     0              0
# emotion_Neutral                                   1              0
# emotion_Sad                                       0              0
# bodypose_Back                                     0              0
# bodypose_Front-Frontish                           1              1
# bodypose_Side                                     0              0

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        # 'items' is a df generated from main df based on batch_size. 
        # items.iterrows() will take item['image_path'] and fetch it to cv2.imread(). '_' means ignore the index we get back from iterrows()
        # cv2.imread() will convert it to a numpy array which can be used by python
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        # target is a dictionary with all gender cols counted against key 'gender_output' and so on.
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# giving random state as 42 to avoid data leak
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15,random_state=42)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head(2)
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 10416  resized/10418.jpg              0  ...                        0              0
# 3495    resized/3496.jpg              0  ...                        0              0
#
# [2 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, 
                                augmentation=ImageDataGenerator(rescale=1./255,
                                                                featurewise_center=True,
                                                                featurewise_std_normalization=True,
#                                                                horizontal_flip=True,vertical_flip=False,rotation_range=20,width_shift_range=.2,
                                                                preprocessing_function=get_random_eraser(v_l=1, v_h=1)))
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False,
                                augmentation=ImageDataGenerator(rescale=1./255,
                                                                featurewise_center=True,
                                                                featurewise_std_normalization=True))

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
# targets is a dictionary that we get from person data generator.
# k will get key value 'age_output' which will be split to get 'age' only
# v will get value of disctionary. We will take how many columns are there in v to understand classes within each class. eg: v.shape[1] will be 2
# for key 'gender_output' because there are 2 sub-categories 'male' & 'female
# these num_units will be later used to build the final model via build_head function
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
one_hot_df.head(3)
# Out:
#       image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 0  resized/1.jpg              0  ...                        1              0
# 1  resized/2.jpg              1  ...                        1              0
# 2  resized/3.jpg              0  ...                        1              0
#
# [3 rows x 28 columns]

# %%
print(one_hot_df[one_hot_df['age_35-45'] == 1].shape[0])
# Out:
# 3435

# %%
col_names = list(one_hot_df.columns.values)
len(col_names)
i = 0
for i in range(len(col_names)):
    print(col_names[i],one_hot_df[one_hot_df[col_names[i]] == 1].shape[0])
# Out:
# image_path 0
# gender_female 5937
# gender_male 7636
# imagequality_Average 7509
# imagequality_Bad 2240
# imagequality_Good 3824
# age_15-25 2494
# age_25-35 5411
# age_35-45 3435
# age_45-55 1490
# age_55+ 743
# weight_normal-healthy 8628
# weight_over-weight 891
# weight_slightly-overweight 3196
# weight_underweight 858
# carryingbag_Daily/Office/Work Bag 4603
# carryingbag_Grocery/Home/Plastic Bag 1321
# carryingbag_None 7649
# footwear_CantSee 5028
# footwear_Fancy 2507
# footwear_Normal 6038
# emotion_Angry/Serious 1500
# emotion_Happy 1609
# emotion_Neutral 9660
# emotion_Sad 804
# bodypose_Back 2207
# bodypose_Front-Frontish 8383
# bodypose_Side 2983

# %%
# To check if images are getting read correctly
from google.colab.patches import cv2_imshow
img = cv2.imread('resized/1.jpg',0)
cv2_imshow(img)
print('type::',type(img))
# Out:
# <PIL.Image.Image image mode=L size=224x224 at 0x7FB058E39AC8>
# type:: <class 'numpy.ndarray'>

# %%
backbone = ResNet50(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
neck = backbone.output  #backbone.output gives the last layer already build by VGG16 on the above statement (block5_maxpool)
neck = Flatten(name="flattener")(neck)  # Adds Flatten layer
neck = Dense(512, activation="relu")(neck) # Adds fully connected layer with Relu Activation
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
def build_tower(in_layer,dp1,dense1,dp2,dense2,act2=None):
    head = Dropout(dp1)(in_layer)
    head = Dense(dense1, activation="relu")(head)
    head = Dropout(dp2)(head)
    head = Dense(dense2, activation=act2)(head)
    return head

# %%
def build_tower02(in_layer,dp1,dense1,act2=None):
    head = Dropout(dp1)(in_layer)
    head = Dense(dense1, activation=act2)(head)
    return head

# %%
def build_head(name, activator,in_layer):
    return Dense(
        num_units[name], activation=activator, name=f"{name}_output"
    )(in_layer)

# %%
# heads
# Calls build_tower function with layers till previous point i.e. in_layer
# For each multi-label class, build_tower adds to in_layer following - dropout -> fully connected layer -> droput -> fully connected layer &  
# returns back to build_head.
# Build_head applies a dense layer with softmax/sigmoid activation on top of this to give final output for that particular class. eg: gender, age etc.
# 'M odel' API will use one 'neck' and connect one 'backbone'(VGG16) with 8 'heads'(below) which are built using build_head & build_tower

# gender = build_head("gender", "sigmoid", build_tower(neck))  #gender is binary classification
# image_quality = build_head("image_quality", "softmax",build_tower(neck)) # image is multi-class single label, can be either good, avg or bad
# age = build_head("age", "softmax",build_tower(neck))  # Age is regression to arbitrary value but here we are didving to groups like 15-25, 25-35, hence multi-class single label
# weight = build_head("weight", "softmax",build_tower(neck)) # weight is multi-class, single label as it can healthy, over or under
# bag = build_head("bag", "softmax",build_tower(neck))  # bag is multi-class, single label 
# footwear = build_head("footwear","softmax", build_tower(neck))  # multi-class, single label 
# emotion = build_head("emotion", "softmax", build_tower(neck))  # multi-class, single label 
# pose = build_head("pose", "softmax",build_tower(neck)) # multi-class, single label 

gender = build_head("gender", "softmax", build_tower(neck,dp1=0.2,dense1=128,dp2=0.3,dense2=128,act2='relu'))  #gender is binary classification
image_quality = build_head("image_quality", "sigmoid",build_tower(neck,dp1=0.2,dense1=256,dp2=0.1,dense2=128)) # image is multi-class single label, can be either good, avg or bad
age = build_head("age", "sigmoid",build_tower(neck,dp1=0.2,dense1=256,dp2=0.1,dense2=128))  # Age is regression to arbitrary value but here we are didving to groups like 15-25, 25-35, hence multi-class single label
weight = build_head("weight", "sigmoid",build_tower(neck,dp1=0.2,dense1=256,dp2=0.1,dense2=128)) # weight is multi-class, single label as it can healthy, over or under
bag = build_head("bag", "sigmoid",build_tower(neck,dp1=0.2,dense1=256,dp2=0.1,dense2=128))  # bag is multi-class, single label 
footwear = build_head("footwear","softmax", build_tower(neck,dp1=0.2,dense1=256,dp2=0.1,dense2=128))  # multi-class, single label 
emotion = build_head("emotion", "sigmoid", build_tower02(neck,dp1=0.2,dense1=256))  # multi-class, single label 
pose = build_head("pose", "sigmoid",build_tower(neck,dp1=0.2,dense1=256,dp2=0.1,dense2=128)) # multi-class, single label
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

# %%
# freeze backbone
#for layer in backbone.layers:
#	print(layer)
#	layer.trainable = False

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True,to_file='model.png')

# %%
# losses = {
# 	"gender_output": "binary_crossentropy",
# 	"image_quality_output": "categorical_crossentropy",
# 	"age_output": "categorical_crossentropy",
# 	"weight_output": "categorical_crossentropy",

# }
# loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.0}
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.004 * 1/(1 + 0.319 * epoch), 10)
opt = SGD(lr=0.003, momentum=0.9)
#opt = SGD(momentum=0.5)
model.compile(
    optimizer=opt,
#   loss = "binary_crossentropy",
    loss={"gender_output":"categorical_crossentropy", 
          "image_quality_output":"binary_crossentropy",
          "age_output":"binary_crossentropy",
          "weight_output":"binary_crossentropy",
          "bag_output":"binary_crossentropy",
          "emotion_output": "binary_crossentropy",
          "pose_output": "binary_crossentropy",
          "footwear_output": "binary_crossentropy"},
    # loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 56, 56, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 56, 56, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 56, 56, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 56, 56, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 56, 56, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 56, 56, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 56, 56, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 56, 56, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 28, 28, 128)  32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 128)  0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 28, 28, 512)  131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 28, 28, 512)  2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 28, 28, 128)  65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 28, 28, 128)  147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 28, 28, 128)  512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 128)  0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 28, 28, 512)  66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 28, 28, 512)  2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 14, 14, 256)  131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# flattener (Flatten)             (None, 100352)       0           activation_49[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          51380736    flattener[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          65664       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          131328      dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 256)          131328      dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 256)          131328      dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          131328      dropout_11[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          131328      dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 256)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 256)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 256)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          16512       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          32896       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          32896       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          32896       dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          32896       dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          32896       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 128)          32896       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 256)          131328      dropout_13[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_3[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_5[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_7[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_9[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_11[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_13[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_16[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            1028        dense_14[0][0]
# ==================================================================================================
# Total params: 76,171,291
# Trainable params: 76,118,171
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=4, 
    epochs=50,
    verbose=1)
#    callbacks=[LearningRateScheduler(scheduler,verbose=1)])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# 359/360 [============================>.] - ETA: 0s - loss: 37.2848 - gender_output_loss: 9.0268 - image_quality_output_loss: 5.3313 - age_output_loss: 3.1878 - weight_output_loss: 2.9114 - bag_output_loss: 4.6167 - footwear_output_loss: 5.8619 - pose_output_loss: 4.0503 - emotion_output_loss: 2.2986 - gender_output_acc: 0.4357 - image_quality_output_acc: 0.6663 - age_output_acc: 0.7972 - weight_output_acc: 0.8140 - bag_output_acc: 0.7084 - footwear_output_acc: 0.6323 - pose_output_acc: 0.7424 - emotion_output_acc: 0.8541
# 360/360 [==============================] - 111s 309ms/step - loss: 37.2817 - gender_output_loss: 9.0283 - image_quality_output_loss: 5.3314 - age_output_loss: 3.1879 - weight_output_loss: 2.9095 - bag_output_loss: 4.6132 - footwear_output_loss: 5.8660 - pose_output_loss: 4.0483 - emotion_output_loss: 2.2971 - gender_output_acc: 0.4356 - image_quality_output_acc: 0.6663 - age_output_acc: 0.7972 - weight_output_acc: 0.8141 - bag_output_acc: 0.7087 - footwear_output_acc: 0.6321 - pose_output_acc: 0.7425 - emotion_output_acc: 0.8542 - val_loss: 37.5945 - val_gender_output_loss: 8.8796 - val_image_quality_output_loss: 5.3727 - val_age_output_loss: 3.2236 - val_weight_output_loss: 2.8481 - val_bag_output_loss: 4.7778 - val_footwear_output_loss: 6.0706 - val_pose_output_loss: 4.0668 - val_emotion_output_loss: 2.3552 - val_gender_output_acc: 0.4491 - val_image_quality_output_acc: 0.6667 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7019 - val_footwear_output_acc: 0.6213 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 2/50
# 360/360 [==============================] - 91s 253ms/step - loss: 39.1494 - gender_output_loss: 9.1000 - image_quality_output_loss: 6.9488 - age_output_loss: 3.2236 - weight_output_loss: 2.9310 - bag_output_loss: 4.6458 - footwear_output_loss: 5.9047 - pose_output_loss: 4.0925 - emotion_output_loss: 2.3030 - gender_output_acc: 0.4354 - image_quality_output_acc: 0.5668 - age_output_acc: 0.8000 - weight_output_acc: 0.8161 - bag_output_acc: 0.7102 - footwear_output_acc: 0.6317 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8563 - val_loss: 39.9459 - val_gender_output_loss: 8.8796 - val_image_quality_output_loss: 7.7242 - val_age_output_loss: 3.2236 - val_weight_output_loss: 2.8481 - val_bag_output_loss: 4.7778 - val_footwear_output_loss: 6.0706 - val_pose_output_loss: 4.0667 - val_emotion_output_loss: 2.3552 - val_gender_output_acc: 0.4491 - val_image_quality_output_acc: 0.5181 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7019 - val_footwear_output_acc: 0.6213 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 3/50
# 359/360 [============================>.] - ETA: 0s - loss: 39.8788 - gender_output_loss: 9.0987 - image_quality_output_loss: 7.6700 - age_output_loss: 3.2236 - weight_output_loss: 2.9408 - bag_output_loss: 4.6560 - footwear_output_loss: 5.9053 - pose_output_loss: 4.0849 - emotion_output_loss: 2.2996 - gender_output_acc: 0.4355 - image_quality_output_acc: 0.5215 - age_output_acc: 0.8000 - weight_output_acc: 0.8165 - bag_output_acc: 0.7096 - footwear_output_acc: 0.6316 - pose_output_acc: 0.7439 - emotion_output_acc: 0.8565
# 360/360 [==============================] - 91s 253ms/step - loss: 39.8727 - gender_output_loss: 9.0972 - image_quality_output_loss: 7.6682 - age_output_loss: 3.2236 - weight_output_loss: 2.9368 - bag_output_loss: 4.6551 - footwear_output_loss: 5.9037 - pose_output_loss: 4.0865 - emotion_output_loss: 2.3016 - gender_output_acc: 0.4356 - image_quality_output_acc: 0.5216 - age_output_acc: 0.8000 - weight_output_acc: 0.8168 - bag_output_acc: 0.7096 - footwear_output_acc: 0.6317 - pose_output_acc: 0.7438 - emotion_output_acc: 0.8564 - val_loss: 39.9460 - val_gender_output_loss: 8.8796 - val_image_quality_output_loss: 7.7242 - val_age_output_loss: 3.2236 - val_weight_output_loss: 2.8481 - val_bag_output_loss: 4.7778 - val_footwear_output_loss: 6.0706 - val_pose_output_loss: 4.0668 - val_emotion_output_loss: 2.3552 - val_gender_output_acc: 0.4491 - val_image_quality_output_acc: 0.5181 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7019 - val_footwear_output_acc: 0.6213 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 4/50
# 360/360 [==============================] - 91s 252ms/step - loss: 39.8759 - gender_output_loss: 9.0972 - image_quality_output_loss: 7.6682 - age_output_loss: 3.2236 - weight_output_loss: 2.9389 - bag_output_loss: 4.6514 - footwear_output_loss: 5.9037 - pose_output_loss: 4.0911 - emotion_output_loss: 2.3019 - gender_output_acc: 0.4356 - image_quality_output_acc: 0.5216 - age_output_acc: 0.8000 - weight_output_acc: 0.8167 - bag_output_acc: 0.7098 - footwear_output_acc: 0.6317 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8556 - val_loss: 39.9460 - val_gender_output_loss: 8.8796 - val_image_quality_output_loss: 7.7242 - val_age_output_loss: 3.2236 - val_weight_output_loss: 2.8481 - val_bag_output_loss: 4.7778 - val_footwear_output_loss: 6.0706 - val_pose_output_loss: 4.0668 - val_emotion_output_loss: 2.3552 - val_gender_output_acc: 0.4491 - val_image_quality_output_acc: 0.5181 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7019 - val_footwear_output_acc: 0.6213 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 5/50
# 360/360 [==============================] - 91s 252ms/step - loss: 11.7744 - gender_output_loss: 2.5319 - image_quality_output_loss: 1.8145 - age_output_loss: 1.0828 - weight_output_loss: 0.9559 - bag_output_loss: 1.4597 - footwear_output_loss: 1.7512 - pose_output_loss: 1.3458 - emotion_output_loss: 0.8326 - gender_output_acc: 0.5243 - image_quality_output_acc: 0.6784 - age_output_acc: 0.7999 - weight_output_acc: 0.8122 - bag_output_acc: 0.7053 - footwear_output_acc: 0.6532 - pose_output_acc: 0.7424 - emotion_output_acc: 0.8532 - val_loss: 4.2747 - val_gender_output_loss: 0.6889 - val_image_quality_output_loss: 0.5739 - val_age_output_loss: 0.4636 - val_weight_output_loss: 0.4248 - val_bag_output_loss: 0.5671 - val_footwear_output_loss: 0.6089 - val_pose_output_loss: 0.5487 - val_emotion_output_loss: 0.3988 - val_gender_output_acc: 0.5509 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7019 - val_footwear_output_acc: 0.6667 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 6/50
# 360/360 [==============================] - 91s 252ms/step - loss: 4.2648 - gender_output_loss: 0.6820 - image_quality_output_loss: 0.5826 - age_output_loss: 0.4656 - weight_output_loss: 0.4330 - bag_output_loss: 0.5534 - footwear_output_loss: 0.5944 - pose_output_loss: 0.5504 - emotion_output_loss: 0.4034 - gender_output_acc: 0.5655 - image_quality_output_acc: 0.6997 - age_output_acc: 0.7999 - weight_output_acc: 0.8168 - bag_output_acc: 0.7099 - footwear_output_acc: 0.6764 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8563 - val_loss: 4.1912 - val_gender_output_loss: 0.6812 - val_image_quality_output_loss: 0.5710 - val_age_output_loss: 0.4585 - val_weight_output_loss: 0.4189 - val_bag_output_loss: 0.5494 - val_footwear_output_loss: 0.5735 - val_pose_output_loss: 0.5464 - val_emotion_output_loss: 0.3922 - val_gender_output_acc: 0.5509 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7019 - val_footwear_output_acc: 0.7107 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 7/50
# 360/360 [==============================] - 91s 254ms/step - loss: 4.2037 - gender_output_loss: 0.6725 - image_quality_output_loss: 0.5791 - age_output_loss: 0.4596 - weight_output_loss: 0.4262 - bag_output_loss: 0.5480 - footwear_output_loss: 0.5781 - pose_output_loss: 0.5461 - emotion_output_loss: 0.3942 - gender_output_acc: 0.5663 - image_quality_output_acc: 0.7005 - age_output_acc: 0.8001 - weight_output_acc: 0.8169 - bag_output_acc: 0.7107 - footwear_output_acc: 0.6918 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8563 - val_loss: 4.1411 - val_gender_output_loss: 0.6609 - val_image_quality_output_loss: 0.5700 - val_age_output_loss: 0.4560 - val_weight_output_loss: 0.4187 - val_bag_output_loss: 0.5477 - val_footwear_output_loss: 0.5535 - val_pose_output_loss: 0.5448 - val_emotion_output_loss: 0.3895 - val_gender_output_acc: 0.5837 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7043 - val_footwear_output_acc: 0.7182 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 8/50
# 360/360 [==============================] - 91s 253ms/step - loss: 4.1502 - gender_output_loss: 0.6513 - image_quality_output_loss: 0.5774 - age_output_loss: 0.4553 - weight_output_loss: 0.4225 - bag_output_loss: 0.5427 - footwear_output_loss: 0.5674 - pose_output_loss: 0.5446 - emotion_output_loss: 0.3889 - gender_output_acc: 0.5871 - image_quality_output_acc: 0.7008 - age_output_acc: 0.7999 - weight_output_acc: 0.8171 - bag_output_acc: 0.7137 - footwear_output_acc: 0.7014 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564 - val_loss: 4.1115 - val_gender_output_loss: 0.6388 - val_image_quality_output_loss: 0.5695 - val_age_output_loss: 0.4536 - val_weight_output_loss: 0.4156 - val_bag_output_loss: 0.5438 - val_footwear_output_loss: 0.5566 - val_pose_output_loss: 0.5438 - val_emotion_output_loss: 0.3898 - val_gender_output_acc: 0.6391 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7063 - val_footwear_output_acc: 0.7124 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 9/50
# 360/360 [==============================] - 91s 253ms/step - loss: 4.1328 - gender_output_loss: 0.6434 - image_quality_output_loss: 0.5789 - age_output_loss: 0.4539 - weight_output_loss: 0.4207 - bag_output_loss: 0.5425 - footwear_output_loss: 0.5626 - pose_output_loss: 0.5450 - emotion_output_loss: 0.3858 - gender_output_acc: 0.6030 - image_quality_output_acc: 0.6986 - age_output_acc: 0.7996 - weight_output_acc: 0.8167 - bag_output_acc: 0.7137 - footwear_output_acc: 0.7054 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8563 - val_loss: 4.1156 - val_gender_output_loss: 0.6408 - val_image_quality_output_loss: 0.5714 - val_age_output_loss: 0.4540 - val_weight_output_loss: 0.4161 - val_bag_output_loss: 0.5424 - val_footwear_output_loss: 0.5596 - val_pose_output_loss: 0.5428 - val_emotion_output_loss: 0.3885 - val_gender_output_acc: 0.6689 - val_image_quality_output_acc: 0.7112 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7092 - val_footwear_output_acc: 0.7046 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 10/50
# 360/360 [==============================] - 91s 252ms/step - loss: 4.1038 - gender_output_loss: 0.6272 - image_quality_output_loss: 0.5783 - age_output_loss: 0.4522 - weight_output_loss: 0.4204 - bag_output_loss: 0.5377 - footwear_output_loss: 0.5612 - pose_output_loss: 0.5425 - emotion_output_loss: 0.3843 - gender_output_acc: 0.6288 - image_quality_output_acc: 0.7001 - age_output_acc: 0.8000 - weight_output_acc: 0.8168 - bag_output_acc: 0.7180 - footwear_output_acc: 0.7052 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8562 - val_loss: 4.0940 - val_gender_output_loss: 0.6296 - val_image_quality_output_loss: 0.5708 - val_age_output_loss: 0.4532 - val_weight_output_loss: 0.4166 - val_bag_output_loss: 0.5400 - val_footwear_output_loss: 0.5536 - val_pose_output_loss: 0.5412 - val_emotion_output_loss: 0.3890 - val_gender_output_acc: 0.6447 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7103 - val_footwear_output_acc: 0.7256 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 11/50
# 360/360 [==============================] - 91s 252ms/step - loss: 4.0774 - gender_output_loss: 0.6090 - image_quality_output_loss: 0.5776 - age_output_loss: 0.4518 - weight_output_loss: 0.4198 - bag_output_loss: 0.5351 - footwear_output_loss: 0.5601 - pose_output_loss: 0.5412 - emotion_output_loss: 0.3826 - gender_output_acc: 0.6424 - image_quality_output_acc: 0.7006 - age_output_acc: 0.8001 - weight_output_acc: 0.8168 - bag_output_acc: 0.7179 - footwear_output_acc: 0.7074 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8564 - val_loss: 4.0743 - val_gender_output_loss: 0.6192 - val_image_quality_output_loss: 0.5702 - val_age_output_loss: 0.4524 - val_weight_output_loss: 0.4165 - val_bag_output_loss: 0.5404 - val_footwear_output_loss: 0.5470 - val_pose_output_loss: 0.5404 - val_emotion_output_loss: 0.3882 - val_gender_output_acc: 0.6562 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7147 - val_footwear_output_acc: 0.7283 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 12/50
# 360/360 [==============================] - 91s 252ms/step - loss: 4.0522 - gender_output_loss: 0.5910 - image_quality_output_loss: 0.5770 - age_output_loss: 0.4516 - weight_output_loss: 0.4191 - bag_output_loss: 0.5354 - footwear_output_loss: 0.5541 - pose_output_loss: 0.5407 - emotion_output_loss: 0.3833 - gender_output_acc: 0.6642 - image_quality_output_acc: 0.7009 - age_output_acc: 0.8000 - weight_output_acc: 0.8169 - bag_output_acc: 0.7206 - footwear_output_acc: 0.7089 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564 - val_loss: 4.0544 - val_gender_output_loss: 0.6001 - val_image_quality_output_loss: 0.5705 - val_age_output_loss: 0.4529 - val_weight_output_loss: 0.4170 - val_bag_output_loss: 0.5384 - val_footwear_output_loss: 0.5465 - val_pose_output_loss: 0.5411 - val_emotion_output_loss: 0.3878 - val_gender_output_acc: 0.6855 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7115 - val_footwear_output_acc: 0.7312 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 13/50
# 360/360 [==============================] - 91s 252ms/step - loss: 4.0384 - gender_output_loss: 0.5843 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4510 - weight_output_loss: 0.4185 - bag_output_loss: 0.5302 - footwear_output_loss: 0.5555 - pose_output_loss: 0.5402 - emotion_output_loss: 0.3820 - gender_output_acc: 0.6687 - image_quality_output_acc: 0.7008 - age_output_acc: 0.7997 - weight_output_acc: 0.8169 - bag_output_acc: 0.7230 - footwear_output_acc: 0.7078 - pose_output_acc: 0.7449 - emotion_output_acc: 0.8564 - val_loss: 4.0573 - val_gender_output_loss: 0.5953 - val_image_quality_output_loss: 0.5710 - val_age_output_loss: 0.4523 - val_weight_output_loss: 0.4168 - val_bag_output_loss: 0.5361 - val_footwear_output_loss: 0.5553 - val_pose_output_loss: 0.5431 - val_emotion_output_loss: 0.3873 - val_gender_output_acc: 0.6840 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7120 - val_footwear_output_acc: 0.7268 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 14/50
# 359/360 [============================>.] - ETA: 0s - loss: 4.0241 - gender_output_loss: 0.5701 - image_quality_output_loss: 0.5773 - age_output_loss: 0.4510 - weight_output_loss: 0.4192 - bag_output_loss: 0.5296 - footwear_output_loss: 0.5542 - pose_output_loss: 0.5403 - emotion_output_loss: 0.3825 - gender_output_acc: 0.6781 - image_quality_output_acc: 0.7005 - age_output_acc: 0.7995 - weight_output_acc: 0.8169 - bag_output_acc: 0.7256 - footwear_output_acc: 0.7115 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8562Epoch 14/50
# 360/360 [==============================] - 91s 253ms/step - loss: 4.0231 - gender_output_loss: 0.5697 - image_quality_output_loss: 0.5772 - age_output_loss: 0.4510 - weight_output_loss: 0.4192 - bag_output_loss: 0.5295 - footwear_output_loss: 0.5539 - pose_output_loss: 0.5403 - emotion_output_loss: 0.3823 - gender_output_acc: 0.6784 - image_quality_output_acc: 0.7006 - age_output_acc: 0.7995 - weight_output_acc: 0.8169 - bag_output_acc: 0.7257 - footwear_output_acc: 0.7117 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8563 - val_loss: 4.0466 - val_gender_output_loss: 0.5986 - val_image_quality_output_loss: 0.5699 - val_age_output_loss: 0.4518 - val_weight_output_loss: 0.4162 - val_bag_output_loss: 0.5360 - val_footwear_output_loss: 0.5465 - val_pose_output_loss: 0.5402 - val_emotion_output_loss: 0.3873 - val_gender_output_acc: 0.6920 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7147 - val_footwear_output_acc: 0.7314 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 15/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.9999 - gender_output_loss: 0.5540 - image_quality_output_loss: 0.5768 - age_output_loss: 0.4501 - weight_output_loss: 0.4184 - bag_output_loss: 0.5278 - footwear_output_loss: 0.5512 - pose_output_loss: 0.5398 - emotion_output_loss: 0.3818 - gender_output_acc: 0.6906 - image_quality_output_acc: 0.7006 - age_output_acc: 0.8001 - weight_output_acc: 0.8171 - bag_output_acc: 0.7268 - footwear_output_acc: 0.7096 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8564 - val_loss: 4.0859 - val_gender_output_loss: 0.6295 - val_image_quality_output_loss: 0.5701 - val_age_output_loss: 0.4531 - val_weight_output_loss: 0.4173 - val_bag_output_loss: 0.5394 - val_footwear_output_loss: 0.5503 - val_pose_output_loss: 0.5384 - val_emotion_output_loss: 0.3878 - val_gender_output_acc: 0.6714 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7135 - val_footwear_output_acc: 0.7334 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 16/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.9711 - gender_output_loss: 0.5289 - image_quality_output_loss: 0.5770 - age_output_loss: 0.4506 - weight_output_loss: 0.4192 - bag_output_loss: 0.5260 - footwear_output_loss: 0.5489 - pose_output_loss: 0.5390 - emotion_output_loss: 0.3816 - gender_output_acc: 0.7132 - image_quality_output_acc: 0.7007 - age_output_acc: 0.7999 - weight_output_acc: 0.8169 - bag_output_acc: 0.7269 - footwear_output_acc: 0.7131 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8563 - val_loss: 4.0589 - val_gender_output_loss: 0.6001 - val_image_quality_output_loss: 0.5697 - val_age_output_loss: 0.4539 - val_weight_output_loss: 0.4168 - val_bag_output_loss: 0.5361 - val_footwear_output_loss: 0.5564 - val_pose_output_loss: 0.5384 - val_emotion_output_loss: 0.3876 - val_gender_output_acc: 0.6744 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7994 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7112 - val_footwear_output_acc: 0.7248 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 17/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.9586 - gender_output_loss: 0.5203 - image_quality_output_loss: 0.5771 - age_output_loss: 0.4503 - weight_output_loss: 0.4185 - bag_output_loss: 0.5225 - footwear_output_loss: 0.5490 - pose_output_loss: 0.5389 - emotion_output_loss: 0.3821 - gender_output_acc: 0.7116 - image_quality_output_acc: 0.7010 - age_output_acc: 0.8004 - weight_output_acc: 0.8166 - bag_output_acc: 0.7313 - footwear_output_acc: 0.7116 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564 - val_loss: 4.0620 - val_gender_output_loss: 0.6041 - val_image_quality_output_loss: 0.5692 - val_age_output_loss: 0.4541 - val_weight_output_loss: 0.4162 - val_bag_output_loss: 0.5393 - val_footwear_output_loss: 0.5503 - val_pose_output_loss: 0.5401 - val_emotion_output_loss: 0.3885 - val_gender_output_acc: 0.6467 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7097 - val_footwear_output_acc: 0.7292 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 18/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.9373 - gender_output_loss: 0.5015 - image_quality_output_loss: 0.5764 - age_output_loss: 0.4492 - weight_output_loss: 0.4181 - bag_output_loss: 0.5209 - footwear_output_loss: 0.5504 - pose_output_loss: 0.5393 - emotion_output_loss: 0.3815 - gender_output_acc: 0.7281 - image_quality_output_acc: 0.7006 - age_output_acc: 0.8008 - weight_output_acc: 0.8168 - bag_output_acc: 0.7343 - footwear_output_acc: 0.7108 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8565 - val_loss: 4.0529 - val_gender_output_loss: 0.5959 - val_image_quality_output_loss: 0.5698 - val_age_output_loss: 0.4532 - val_weight_output_loss: 0.4183 - val_bag_output_loss: 0.5374 - val_footwear_output_loss: 0.5505 - val_pose_output_loss: 0.5395 - val_emotion_output_loss: 0.3883 - val_gender_output_acc: 0.7021 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8218 - val_bag_output_acc: 0.7177 - val_footwear_output_acc: 0.7258 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 19/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.9004 - gender_output_loss: 0.4737 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4498 - weight_output_loss: 0.4184 - bag_output_loss: 0.5200 - footwear_output_loss: 0.5425 - pose_output_loss: 0.5379 - emotion_output_loss: 0.3814 - gender_output_acc: 0.7507 - image_quality_output_acc: 0.7007 - age_output_acc: 0.8006 - weight_output_acc: 0.8168 - bag_output_acc: 0.7335 - footwear_output_acc: 0.7169 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8564 - val_loss: 4.0360 - val_gender_output_loss: 0.5833 - val_image_quality_output_loss: 0.5697 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4180 - val_bag_output_loss: 0.5365 - val_footwear_output_loss: 0.5485 - val_pose_output_loss: 0.5390 - val_emotion_output_loss: 0.3876 - val_gender_output_acc: 0.6976 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7196 - val_footwear_output_acc: 0.7327 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 20/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.8870 - gender_output_loss: 0.4622 - image_quality_output_loss: 0.5771 - age_output_loss: 0.4493 - weight_output_loss: 0.4186 - bag_output_loss: 0.5159 - footwear_output_loss: 0.5439 - pose_output_loss: 0.5380 - emotion_output_loss: 0.3819 - gender_output_acc: 0.7544 - image_quality_output_acc: 0.7007 - age_output_acc: 0.8001 - weight_output_acc: 0.8167 - bag_output_acc: 0.7389 - footwear_output_acc: 0.7151 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8563 - val_loss: 4.0425 - val_gender_output_loss: 0.5881 - val_image_quality_output_loss: 0.5699 - val_age_output_loss: 0.4545 - val_weight_output_loss: 0.4171 - val_bag_output_loss: 0.5338 - val_footwear_output_loss: 0.5521 - val_pose_output_loss: 0.5391 - val_emotion_output_loss: 0.3880 - val_gender_output_acc: 0.6830 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7196 - val_footwear_output_acc: 0.7268 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 21/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.8639 - gender_output_loss: 0.4440 - image_quality_output_loss: 0.5768 - age_output_loss: 0.4494 - weight_output_loss: 0.4192 - bag_output_loss: 0.5157 - footwear_output_loss: 0.5396 - pose_output_loss: 0.5375 - emotion_output_loss: 0.3818 - gender_output_acc: 0.7599 - image_quality_output_acc: 0.7008 - age_output_acc: 0.8005 - weight_output_acc: 0.8169 - bag_output_acc: 0.7363 - footwear_output_acc: 0.7183 - pose_output_acc: 0.7449 - emotion_output_acc: 0.8565 - val_loss: 4.0430 - val_gender_output_loss: 0.5937 - val_image_quality_output_loss: 0.5696 - val_age_output_loss: 0.4527 - val_weight_output_loss: 0.4172 - val_bag_output_loss: 0.5364 - val_footwear_output_loss: 0.5479 - val_pose_output_loss: 0.5377 - val_emotion_output_loss: 0.3879 - val_gender_output_acc: 0.6976 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7996 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7174 - val_footwear_output_acc: 0.7240 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 22/50
# 360/360 [==============================] - 91s 254ms/step - loss: 3.8632 - gender_output_loss: 0.4350 - image_quality_output_loss: 0.5769 - age_output_loss: 0.4501 - weight_output_loss: 0.4186 - bag_output_loss: 0.5156 - footwear_output_loss: 0.5471 - pose_output_loss: 0.5381 - emotion_output_loss: 0.3817 - gender_output_acc: 0.7664 - image_quality_output_acc: 0.7005 - age_output_acc: 0.7999 - weight_output_acc: 0.8167 - bag_output_acc: 0.7404 - footwear_output_acc: 0.7102 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564 - val_loss: 4.0576 - val_gender_output_loss: 0.6053 - val_image_quality_output_loss: 0.5712 - val_age_output_loss: 0.4528 - val_weight_output_loss: 0.4165 - val_bag_output_loss: 0.5351 - val_footwear_output_loss: 0.5499 - val_pose_output_loss: 0.5391 - val_emotion_output_loss: 0.3877 - val_gender_output_acc: 0.7021 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7251 - val_footwear_output_acc: 0.7300 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 23/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.8315 - gender_output_loss: 0.4151 - image_quality_output_loss: 0.5763 - age_output_loss: 0.4493 - weight_output_loss: 0.4193 - bag_output_loss: 0.5121 - footwear_output_loss: 0.5411 - pose_output_loss: 0.5369 - emotion_output_loss: 0.3814 - gender_output_acc: 0.7766 - image_quality_output_acc: 0.7004 - age_output_acc: 0.8006 - weight_output_acc: 0.8165 - bag_output_acc: 0.7412 - footwear_output_acc: 0.7135 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8565 - val_loss: 4.0502 - val_gender_output_loss: 0.5975 - val_image_quality_output_loss: 0.5703 - val_age_output_loss: 0.4524 - val_weight_output_loss: 0.4167 - val_bag_output_loss: 0.5348 - val_footwear_output_loss: 0.5526 - val_pose_output_loss: 0.5384 - val_emotion_output_loss: 0.3876 - val_gender_output_acc: 0.6971 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7186 - val_footwear_output_acc: 0.7245 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 24/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.8278 - gender_output_loss: 0.4075 - image_quality_output_loss: 0.5763 - age_output_loss: 0.4500 - weight_output_loss: 0.4186 - bag_output_loss: 0.5127 - footwear_output_loss: 0.5440 - pose_output_loss: 0.5373 - emotion_output_loss: 0.3815 - gender_output_acc: 0.7783 - image_quality_output_acc: 0.7005 - age_output_acc: 0.8005 - weight_output_acc: 0.8166 - bag_output_acc: 0.7405 - footwear_output_acc: 0.7120 - pose_output_acc: 0.7449 - emotion_output_acc: 0.8565 - val_loss: 4.0622 - val_gender_output_loss: 0.6172 - val_image_quality_output_loss: 0.5704 - val_age_output_loss: 0.4524 - val_weight_output_loss: 0.4166 - val_bag_output_loss: 0.5331 - val_footwear_output_loss: 0.5452 - val_pose_output_loss: 0.5398 - val_emotion_output_loss: 0.3876 - val_gender_output_acc: 0.7067 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7209 - val_footwear_output_acc: 0.7305 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 25/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.7849 - gender_output_loss: 0.3734 - image_quality_output_loss: 0.5761 - age_output_loss: 0.4491 - weight_output_loss: 0.4184 - bag_output_loss: 0.5101 - footwear_output_loss: 0.5385 - pose_output_loss: 0.5377 - emotion_output_loss: 0.3817 - gender_output_acc: 0.7979 - image_quality_output_acc: 0.7008 - age_output_acc: 0.8009 - weight_output_acc: 0.8173 - bag_output_acc: 0.7444 - footwear_output_acc: 0.7157 - pose_output_acc: 0.7445 - emotion_output_acc: 0.8565
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7849 - gender_output_loss: 0.3729 - image_quality_output_loss: 0.5760 - age_output_loss: 0.4492 - weight_output_loss: 0.4186 - bag_output_loss: 0.5103 - footwear_output_loss: 0.5384 - pose_output_loss: 0.5377 - emotion_output_loss: 0.3819 - gender_output_acc: 0.7981 - image_quality_output_acc: 0.7008 - age_output_acc: 0.8009 - weight_output_acc: 0.8171 - bag_output_acc: 0.7444 - footwear_output_acc: 0.7159 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8564 - val_loss: 4.0855 - val_gender_output_loss: 0.6192 - val_image_quality_output_loss: 0.5718 - val_age_output_loss: 0.4530 - val_weight_output_loss: 0.4175 - val_bag_output_loss: 0.5328 - val_footwear_output_loss: 0.5627 - val_pose_output_loss: 0.5402 - val_emotion_output_loss: 0.3882 - val_gender_output_acc: 0.6941 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7203 - val_footwear_output_acc: 0.7151 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 26/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7771 - gender_output_loss: 0.3652 - image_quality_output_loss: 0.5768 - age_output_loss: 0.4499 - weight_output_loss: 0.4185 - bag_output_loss: 0.5087 - footwear_output_loss: 0.5398 - pose_output_loss: 0.5362 - emotion_output_loss: 0.3819 - gender_output_acc: 0.8001 - image_quality_output_acc: 0.7005 - age_output_acc: 0.8004 - weight_output_acc: 0.8168 - bag_output_acc: 0.7436 - footwear_output_acc: 0.7150 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8563 - val_loss: 4.1124 - val_gender_output_loss: 0.6587 - val_image_quality_output_loss: 0.5709 - val_age_output_loss: 0.4531 - val_weight_output_loss: 0.4174 - val_bag_output_loss: 0.5328 - val_footwear_output_loss: 0.5518 - val_pose_output_loss: 0.5401 - val_emotion_output_loss: 0.3875 - val_gender_output_acc: 0.7046 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8225 - val_bag_output_acc: 0.7199 - val_footwear_output_acc: 0.7312 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 27/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7655 - gender_output_loss: 0.3542 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4500 - weight_output_loss: 0.4182 - bag_output_loss: 0.5072 - footwear_output_loss: 0.5405 - pose_output_loss: 0.5371 - emotion_output_loss: 0.3816 - gender_output_acc: 0.8068 - image_quality_output_acc: 0.7002 - age_output_acc: 0.8006 - weight_output_acc: 0.8169 - bag_output_acc: 0.7443 - footwear_output_acc: 0.7155 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564 - val_loss: 4.1894 - val_gender_output_loss: 0.7325 - val_image_quality_output_loss: 0.5692 - val_age_output_loss: 0.4522 - val_weight_output_loss: 0.4172 - val_bag_output_loss: 0.5396 - val_footwear_output_loss: 0.5523 - val_pose_output_loss: 0.5384 - val_emotion_output_loss: 0.3880 - val_gender_output_acc: 0.6900 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7161 - val_footwear_output_acc: 0.7233 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 28/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7591 - gender_output_loss: 0.3527 - image_quality_output_loss: 0.5762 - age_output_loss: 0.4500 - weight_output_loss: 0.4186 - bag_output_loss: 0.5080 - footwear_output_loss: 0.5373 - pose_output_loss: 0.5353 - emotion_output_loss: 0.3811 - gender_output_acc: 0.8060 - image_quality_output_acc: 0.7007 - age_output_acc: 0.8003 - weight_output_acc: 0.8170 - bag_output_acc: 0.7474 - footwear_output_acc: 0.7200 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8566 - val_loss: 4.1419 - val_gender_output_loss: 0.6915 - val_image_quality_output_loss: 0.5702 - val_age_output_loss: 0.4529 - val_weight_output_loss: 0.4171 - val_bag_output_loss: 0.5351 - val_footwear_output_loss: 0.5483 - val_pose_output_loss: 0.5396 - val_emotion_output_loss: 0.3871 - val_gender_output_acc: 0.6804 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7992 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7152 - val_footwear_output_acc: 0.7253 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 29/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7768 - gender_output_loss: 0.3600 - image_quality_output_loss: 0.5761 - age_output_loss: 0.4492 - weight_output_loss: 0.4180 - bag_output_loss: 0.5120 - footwear_output_loss: 0.5419 - pose_output_loss: 0.5377 - emotion_output_loss: 0.3820 - gender_output_acc: 0.7978 - image_quality_output_acc: 0.7012 - age_output_acc: 0.8009 - weight_output_acc: 0.8171 - bag_output_acc: 0.7446 - footwear_output_acc: 0.7142 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8564 - val_loss: 4.1180 - val_gender_output_loss: 0.6550 - val_image_quality_output_loss: 0.5703 - val_age_output_loss: 0.4527 - val_weight_output_loss: 0.4179 - val_bag_output_loss: 0.5358 - val_footwear_output_loss: 0.5542 - val_pose_output_loss: 0.5446 - val_emotion_output_loss: 0.3875 - val_gender_output_acc: 0.6996 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7189 - val_footwear_output_acc: 0.7275 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 30/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7405 - gender_output_loss: 0.3370 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4495 - weight_output_loss: 0.4182 - bag_output_loss: 0.5067 - footwear_output_loss: 0.5341 - pose_output_loss: 0.5363 - emotion_output_loss: 0.3819 - gender_output_acc: 0.8112 - image_quality_output_acc: 0.7000 - age_output_acc: 0.8002 - weight_output_acc: 0.8171 - bag_output_acc: 0.7481 - footwear_output_acc: 0.7198 - pose_output_acc: 0.7451 - emotion_output_acc: 0.8563 - val_loss: 4.1893 - val_gender_output_loss: 0.7374 - val_image_quality_output_loss: 0.5703 - val_age_output_loss: 0.4525 - val_weight_output_loss: 0.4172 - val_bag_output_loss: 0.5351 - val_footwear_output_loss: 0.5529 - val_pose_output_loss: 0.5366 - val_emotion_output_loss: 0.3872 - val_gender_output_acc: 0.7067 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8003 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7154 - val_footwear_output_acc: 0.7238 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 31/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.7145 - gender_output_loss: 0.3148 - image_quality_output_loss: 0.5765 - age_output_loss: 0.4499 - weight_output_loss: 0.4184 - bag_output_loss: 0.5026 - footwear_output_loss: 0.5358 - pose_output_loss: 0.5349 - emotion_output_loss: 0.3817 - gender_output_acc: 0.8232 - image_quality_output_acc: 0.6996 - age_output_acc: 0.7997 - weight_output_acc: 0.8169 - bag_output_acc: 0.7547 - footwear_output_acc: 0.7174 - pose_output_acc: 0.7451 - emotion_output_acc: 0.8565Epoch 31/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.7151 - gender_output_loss: 0.3148 - image_quality_output_loss: 0.5766 - age_output_loss: 0.4499 - weight_output_loss: 0.4185 - bag_output_loss: 0.5025 - footwear_output_loss: 0.5360 - pose_output_loss: 0.5351 - emotion_output_loss: 0.3817 - gender_output_acc: 0.8232 - image_quality_output_acc: 0.6995 - age_output_acc: 0.7997 - weight_output_acc: 0.8168 - bag_output_acc: 0.7547 - footwear_output_acc: 0.7173 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8564 - val_loss: 4.1462 - val_gender_output_loss: 0.6742 - val_image_quality_output_loss: 0.5701 - val_age_output_loss: 0.4536 - val_weight_output_loss: 0.4173 - val_bag_output_loss: 0.5358 - val_footwear_output_loss: 0.5646 - val_pose_output_loss: 0.5429 - val_emotion_output_loss: 0.3878 - val_gender_output_acc: 0.7051 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7203 - val_footwear_output_acc: 0.7167 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 32/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.7192 - gender_output_loss: 0.3145 - image_quality_output_loss: 0.5764 - age_output_loss: 0.4495 - weight_output_loss: 0.4193 - bag_output_loss: 0.5084 - footwear_output_loss: 0.5327 - pose_output_loss: 0.5364 - emotion_output_loss: 0.3820 - gender_output_acc: 0.8214 - image_quality_output_acc: 0.7005 - age_output_acc: 0.8005 - weight_output_acc: 0.8170 - bag_output_acc: 0.7492 - footwear_output_acc: 0.7223 - pose_output_acc: 0.7442 - emotion_output_acc: 0.8564 - val_loss: 4.1608 - val_gender_output_loss: 0.6845 - val_image_quality_output_loss: 0.5694 - val_age_output_loss: 0.4523 - val_weight_output_loss: 0.4174 - val_bag_output_loss: 0.5328 - val_footwear_output_loss: 0.5763 - val_pose_output_loss: 0.5401 - val_emotion_output_loss: 0.3879 - val_gender_output_acc: 0.7127 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7211 - val_footwear_output_acc: 0.7040 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 33/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.7034 - gender_output_loss: 0.3011 - image_quality_output_loss: 0.5764 - age_output_loss: 0.4499 - weight_output_loss: 0.4184 - bag_output_loss: 0.5075 - footwear_output_loss: 0.5340 - pose_output_loss: 0.5337 - emotion_output_loss: 0.3823 - gender_output_acc: 0.8263 - image_quality_output_acc: 0.7003 - age_output_acc: 0.8001 - weight_output_acc: 0.8170 - bag_output_acc: 0.7485 - footwear_output_acc: 0.7217 - pose_output_acc: 0.7449 - emotion_output_acc: 0.8562Epoch 33/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.7026 - gender_output_loss: 0.3013 - image_quality_output_loss: 0.5763 - age_output_loss: 0.4500 - weight_output_loss: 0.4184 - bag_output_loss: 0.5072 - footwear_output_loss: 0.5339 - pose_output_loss: 0.5336 - emotion_output_loss: 0.3820 - gender_output_acc: 0.8265 - image_quality_output_acc: 0.7004 - age_output_acc: 0.8001 - weight_output_acc: 0.8170 - bag_output_acc: 0.7489 - footwear_output_acc: 0.7217 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8564 - val_loss: 4.2088 - val_gender_output_loss: 0.7525 - val_image_quality_output_loss: 0.5721 - val_age_output_loss: 0.4530 - val_weight_output_loss: 0.4183 - val_bag_output_loss: 0.5350 - val_footwear_output_loss: 0.5493 - val_pose_output_loss: 0.5405 - val_emotion_output_loss: 0.3883 - val_gender_output_acc: 0.7102 - val_image_quality_output_acc: 0.7103 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7151 - val_footwear_output_acc: 0.7300 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 34/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.6797 - gender_output_loss: 0.2885 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4498 - weight_output_loss: 0.4185 - bag_output_loss: 0.5057 - footwear_output_loss: 0.5232 - pose_output_loss: 0.5359 - emotion_output_loss: 0.3815 - gender_output_acc: 0.8381 - image_quality_output_acc: 0.7004 - age_output_acc: 0.8007 - weight_output_acc: 0.8166 - bag_output_acc: 0.7508 - footwear_output_acc: 0.7321 - pose_output_acc: 0.7445 - emotion_output_acc: 0.8565 - val_loss: 4.2099 - val_gender_output_loss: 0.7180 - val_image_quality_output_loss: 0.5696 - val_age_output_loss: 0.4525 - val_weight_output_loss: 0.4167 - val_bag_output_loss: 0.5347 - val_footwear_output_loss: 0.5875 - val_pose_output_loss: 0.5439 - val_emotion_output_loss: 0.3871 - val_gender_output_acc: 0.6946 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7186 - val_footwear_output_acc: 0.6825 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 35/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.6630 - gender_output_loss: 0.2773 - image_quality_output_loss: 0.5758 - age_output_loss: 0.4501 - weight_output_loss: 0.4188 - bag_output_loss: 0.5030 - footwear_output_loss: 0.5209 - pose_output_loss: 0.5350 - emotion_output_loss: 0.3821 - gender_output_acc: 0.8417 - image_quality_output_acc: 0.7011 - age_output_acc: 0.8003 - weight_output_acc: 0.8168 - bag_output_acc: 0.7537 - footwear_output_acc: 0.7354 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564 - val_loss: 4.3400 - val_gender_output_loss: 0.8548 - val_image_quality_output_loss: 0.5695 - val_age_output_loss: 0.4527 - val_weight_output_loss: 0.4178 - val_bag_output_loss: 0.5376 - val_footwear_output_loss: 0.5756 - val_pose_output_loss: 0.5445 - val_emotion_output_loss: 0.3875 - val_gender_output_acc: 0.6996 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7147 - val_footwear_output_acc: 0.6999 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 36/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.6409 - gender_output_loss: 0.2651 - image_quality_output_loss: 0.5759 - age_output_loss: 0.4505 - weight_output_loss: 0.4190 - bag_output_loss: 0.5041 - footwear_output_loss: 0.5097 - pose_output_loss: 0.5347 - emotion_output_loss: 0.3819 - gender_output_acc: 0.8451 - image_quality_output_acc: 0.7005 - age_output_acc: 0.8001 - weight_output_acc: 0.8169 - bag_output_acc: 0.7534 - footwear_output_acc: 0.7450 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8565 - val_loss: 4.3043 - val_gender_output_loss: 0.8186 - val_image_quality_output_loss: 0.5701 - val_age_output_loss: 0.4528 - val_weight_output_loss: 0.4177 - val_bag_output_loss: 0.5378 - val_footwear_output_loss: 0.5796 - val_pose_output_loss: 0.5404 - val_emotion_output_loss: 0.3872 - val_gender_output_acc: 0.7001 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8222 - val_bag_output_acc: 0.7172 - val_footwear_output_acc: 0.6971 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 37/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.6437 - gender_output_loss: 0.2686 - image_quality_output_loss: 0.5759 - age_output_loss: 0.4495 - weight_output_loss: 0.4184 - bag_output_loss: 0.5028 - footwear_output_loss: 0.5112 - pose_output_loss: 0.5348 - emotion_output_loss: 0.3824 - gender_output_acc: 0.8447 - image_quality_output_acc: 0.7013 - age_output_acc: 0.8005 - weight_output_acc: 0.8167 - bag_output_acc: 0.7538 - footwear_output_acc: 0.7424 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8564 - val_loss: 4.2074 - val_gender_output_loss: 0.6885 - val_image_quality_output_loss: 0.5721 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4175 - val_bag_output_loss: 0.5349 - val_footwear_output_loss: 0.6094 - val_pose_output_loss: 0.5429 - val_emotion_output_loss: 0.3888 - val_gender_output_acc: 0.7188 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8001 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7169 - val_footwear_output_acc: 0.6769 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 38/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.6236 - gender_output_loss: 0.2501 - image_quality_output_loss: 0.5763 - age_output_loss: 0.4499 - weight_output_loss: 0.4189 - bag_output_loss: 0.5041 - footwear_output_loss: 0.5060 - pose_output_loss: 0.5360 - emotion_output_loss: 0.3823 - gender_output_acc: 0.8502 - image_quality_output_acc: 0.7002 - age_output_acc: 0.8013 - weight_output_acc: 0.8171 - bag_output_acc: 0.7514 - footwear_output_acc: 0.7454 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8565Epoch 38/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.6229 - gender_output_loss: 0.2499 - image_quality_output_loss: 0.5762 - age_output_loss: 0.4499 - weight_output_loss: 0.4189 - bag_output_loss: 0.5037 - footwear_output_loss: 0.5058 - pose_output_loss: 0.5361 - emotion_output_loss: 0.3824 - gender_output_acc: 0.8501 - image_quality_output_acc: 0.7003 - age_output_acc: 0.8013 - weight_output_acc: 0.8171 - bag_output_acc: 0.7515 - footwear_output_acc: 0.7456 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8564 - val_loss: 4.2997 - val_gender_output_loss: 0.7810 - val_image_quality_output_loss: 0.5697 - val_age_output_loss: 0.4529 - val_weight_output_loss: 0.4183 - val_bag_output_loss: 0.5371 - val_footwear_output_loss: 0.6084 - val_pose_output_loss: 0.5447 - val_emotion_output_loss: 0.3875 - val_gender_output_acc: 0.7077 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7993 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7105 - val_footwear_output_acc: 0.6788 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 39/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.5898 - gender_output_loss: 0.2352 - image_quality_output_loss: 0.5762 - age_output_loss: 0.4503 - weight_output_loss: 0.4188 - bag_output_loss: 0.5029 - footwear_output_loss: 0.4891 - pose_output_loss: 0.5352 - emotion_output_loss: 0.3822 - gender_output_acc: 0.8594 - image_quality_output_acc: 0.7002 - age_output_acc: 0.8003 - weight_output_acc: 0.8170 - bag_output_acc: 0.7525 - footwear_output_acc: 0.7568 - pose_output_acc: 0.7442 - emotion_output_acc: 0.8564 - val_loss: 4.3182 - val_gender_output_loss: 0.7605 - val_image_quality_output_loss: 0.5717 - val_age_output_loss: 0.4526 - val_weight_output_loss: 0.4169 - val_bag_output_loss: 0.5339 - val_footwear_output_loss: 0.6505 - val_pose_output_loss: 0.5443 - val_emotion_output_loss: 0.3878 - val_gender_output_acc: 0.7092 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7996 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7149 - val_footwear_output_acc: 0.6650 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 40/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.6435 - gender_output_loss: 0.2698 - image_quality_output_loss: 0.5763 - age_output_loss: 0.4511 - weight_output_loss: 0.4188 - bag_output_loss: 0.5064 - footwear_output_loss: 0.5041 - pose_output_loss: 0.5348 - emotion_output_loss: 0.3823 - gender_output_acc: 0.8458 - image_quality_output_acc: 0.7004 - age_output_acc: 0.7999 - weight_output_acc: 0.8172 - bag_output_acc: 0.7510 - footwear_output_acc: 0.7485 - pose_output_acc: 0.7445 - emotion_output_acc: 0.8564Epoch 40/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.6442 - gender_output_loss: 0.2704 - image_quality_output_loss: 0.5761 - age_output_loss: 0.4512 - weight_output_loss: 0.4190 - bag_output_loss: 0.5061 - footwear_output_loss: 0.5042 - pose_output_loss: 0.5348 - emotion_output_loss: 0.3824 - gender_output_acc: 0.8457 - image_quality_output_acc: 0.7005 - age_output_acc: 0.7999 - weight_output_acc: 0.8170 - bag_output_acc: 0.7512 - footwear_output_acc: 0.7484 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8564 - val_loss: 4.1718 - val_gender_output_loss: 0.6650 - val_image_quality_output_loss: 0.5712 - val_age_output_loss: 0.4540 - val_weight_output_loss: 0.4174 - val_bag_output_loss: 0.5383 - val_footwear_output_loss: 0.5912 - val_pose_output_loss: 0.5457 - val_emotion_output_loss: 0.3889 - val_gender_output_acc: 0.7152 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7112 - val_footwear_output_acc: 0.6858 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 41/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.7746 - gender_output_loss: 0.3515 - image_quality_output_loss: 0.5773 - age_output_loss: 0.4509 - weight_output_loss: 0.4195 - bag_output_loss: 0.5150 - footwear_output_loss: 0.5407 - pose_output_loss: 0.5378 - emotion_output_loss: 0.3819 - gender_output_acc: 0.8111 - image_quality_output_acc: 0.7008 - age_output_acc: 0.8000 - weight_output_acc: 0.8167 - bag_output_acc: 0.7431 - footwear_output_acc: 0.7230 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8565 - val_loss: 4.2800 - val_gender_output_loss: 0.7224 - val_image_quality_output_loss: 0.5712 - val_age_output_loss: 0.4532 - val_weight_output_loss: 0.4185 - val_bag_output_loss: 0.5421 - val_footwear_output_loss: 0.6388 - val_pose_output_loss: 0.5447 - val_emotion_output_loss: 0.3891 - val_gender_output_acc: 0.6855 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7117 - val_footwear_output_acc: 0.6485 - val_pose_output_acc: 0.7438 - val_emotion_output_acc: 0.8531
# Epoch 42/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.6995 - gender_output_loss: 0.2992 - image_quality_output_loss: 0.5760 - age_output_loss: 0.4506 - weight_output_loss: 0.4192 - bag_output_loss: 0.5127 - footwear_output_loss: 0.5221 - pose_output_loss: 0.5376 - emotion_output_loss: 0.3823 - gender_output_acc: 0.8331 - image_quality_output_acc: 0.6992 - age_output_acc: 0.8001 - weight_output_acc: 0.8168 - bag_output_acc: 0.7452 - footwear_output_acc: 0.7377 - pose_output_acc: 0.7443 - emotion_output_acc: 0.8564 - val_loss: 4.2393 - val_gender_output_loss: 0.7524 - val_image_quality_output_loss: 0.5717 - val_age_output_loss: 0.4533 - val_weight_output_loss: 0.4183 - val_bag_output_loss: 0.5368 - val_footwear_output_loss: 0.5750 - val_pose_output_loss: 0.5423 - val_emotion_output_loss: 0.3894 - val_gender_output_acc: 0.7112 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7139 - val_footwear_output_acc: 0.7045 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 43/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.8002 - gender_output_loss: 0.3620 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4521 - weight_output_loss: 0.4200 - bag_output_loss: 0.5205 - footwear_output_loss: 0.5466 - pose_output_loss: 0.5396 - emotion_output_loss: 0.3827 - gender_output_acc: 0.8049 - image_quality_output_acc: 0.7001 - age_output_acc: 0.8002 - weight_output_acc: 0.8171 - bag_output_acc: 0.7398 - footwear_output_acc: 0.7207 - pose_output_acc: 0.7450 - emotion_output_acc: 0.8565 - val_loss: 4.1919 - val_gender_output_loss: 0.6698 - val_image_quality_output_loss: 0.5716 - val_age_output_loss: 0.4540 - val_weight_output_loss: 0.4179 - val_bag_output_loss: 0.5429 - val_footwear_output_loss: 0.6048 - val_pose_output_loss: 0.5425 - val_emotion_output_loss: 0.3883 - val_gender_output_acc: 0.6376 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7073 - val_footwear_output_acc: 0.6717 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 43/50
# Epoch 44/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.7782 - gender_output_loss: 0.3508 - image_quality_output_loss: 0.5772 - age_output_loss: 0.4508 - weight_output_loss: 0.4196 - bag_output_loss: 0.5172 - footwear_output_loss: 0.5419 - pose_output_loss: 0.5378 - emotion_output_loss: 0.3828 - gender_output_acc: 0.8040 - image_quality_output_acc: 0.7004 - age_output_acc: 0.8000 - weight_output_acc: 0.8169 - bag_output_acc: 0.7431 - footwear_output_acc: 0.7244 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8564 - val_loss: 4.3181 - val_gender_output_loss: 0.8189 - val_image_quality_output_loss: 0.5721 - val_age_output_loss: 0.4533 - val_weight_output_loss: 0.4175 - val_bag_output_loss: 0.5381 - val_footwear_output_loss: 0.5886 - val_pose_output_loss: 0.5396 - val_emotion_output_loss: 0.3899 - val_gender_output_acc: 0.6759 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7182 - val_footwear_output_acc: 0.6897 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 45/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.6319 - gender_output_loss: 0.2528 - image_quality_output_loss: 0.5768 - age_output_loss: 0.4510 - weight_output_loss: 0.4195 - bag_output_loss: 0.5102 - footwear_output_loss: 0.5023 - pose_output_loss: 0.5369 - emotion_output_loss: 0.3826 - gender_output_acc: 0.8589 - image_quality_output_acc: 0.7003 - age_output_acc: 0.8004 - weight_output_acc: 0.8168 - bag_output_acc: 0.7479 - footwear_output_acc: 0.7486 - pose_output_acc: 0.7448 - emotion_output_acc: 0.8565 - val_loss: 4.3172 - val_gender_output_loss: 0.7675 - val_image_quality_output_loss: 0.5714 - val_age_output_loss: 0.4538 - val_weight_output_loss: 0.4177 - val_bag_output_loss: 0.5391 - val_footwear_output_loss: 0.6345 - val_pose_output_loss: 0.5452 - val_emotion_output_loss: 0.3881 - val_gender_output_acc: 0.6895 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8003 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7124 - val_footwear_output_acc: 0.6700 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 46/50
# 359/360 [============================>.] - ETA: 0s - loss: 3.5852 - gender_output_loss: 0.2305 - image_quality_output_loss: 0.5761 - age_output_loss: 0.4504 - weight_output_loss: 0.4187 - bag_output_loss: 0.5096 - footwear_output_loss: 0.4822 - pose_output_loss: 0.5354 - emotion_output_loss: 0.3822 - gender_output_acc: 0.8775 - image_quality_output_acc: 0.6995 - age_output_acc: 0.8005 - weight_output_acc: 0.8167 - bag_output_acc: 0.7489 - footwear_output_acc: 0.7636 - pose_output_acc: 0.7447 - emotion_output_acc: 0.8564Epoch 46/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.5847 - gender_output_loss: 0.2307 - image_quality_output_loss: 0.5761 - age_output_loss: 0.4505 - weight_output_loss: 0.4184 - bag_output_loss: 0.5094 - footwear_output_loss: 0.4823 - pose_output_loss: 0.5354 - emotion_output_loss: 0.3820 - gender_output_acc: 0.8773 - image_quality_output_acc: 0.6995 - age_output_acc: 0.8005 - weight_output_acc: 0.8169 - bag_output_acc: 0.7490 - footwear_output_acc: 0.7635 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8566 - val_loss: 4.3092 - val_gender_output_loss: 0.7697 - val_image_quality_output_loss: 0.5712 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4173 - val_bag_output_loss: 0.5328 - val_footwear_output_loss: 0.6315 - val_pose_output_loss: 0.5452 - val_emotion_output_loss: 0.3880 - val_gender_output_acc: 0.7223 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7998 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7177 - val_footwear_output_acc: 0.6798 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 47/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.5575 - gender_output_loss: 0.2092 - image_quality_output_loss: 0.5758 - age_output_loss: 0.4510 - weight_output_loss: 0.4193 - bag_output_loss: 0.5059 - footwear_output_loss: 0.4775 - pose_output_loss: 0.5364 - emotion_output_loss: 0.3824 - gender_output_acc: 0.9036 - image_quality_output_acc: 0.7002 - age_output_acc: 0.8004 - weight_output_acc: 0.8168 - bag_output_acc: 0.7519 - footwear_output_acc: 0.7659 - pose_output_acc: 0.7446 - emotion_output_acc: 0.8564 - val_loss: 4.3680 - val_gender_output_loss: 0.7647 - val_image_quality_output_loss: 0.5721 - val_age_output_loss: 0.4543 - val_weight_output_loss: 0.4187 - val_bag_output_loss: 0.5416 - val_footwear_output_loss: 0.6792 - val_pose_output_loss: 0.5485 - val_emotion_output_loss: 0.3888 - val_gender_output_acc: 0.6769 - val_image_quality_output_acc: 0.7050 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7127 - val_footwear_output_acc: 0.6376 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 48/50
# 360/360 [==============================] - 91s 253ms/step - loss: 3.5992 - gender_output_loss: 0.2377 - image_quality_output_loss: 0.5761 - age_output_loss: 0.4507 - weight_output_loss: 0.4191 - bag_output_loss: 0.5070 - footwear_output_loss: 0.4894 - pose_output_loss: 0.5362 - emotion_output_loss: 0.3829 - gender_output_acc: 0.8866 - image_quality_output_acc: 0.7001 - age_output_acc: 0.8002 - weight_output_acc: 0.8167 - bag_output_acc: 0.7496 - footwear_output_acc: 0.7603 - pose_output_acc: 0.7449 - emotion_output_acc: 0.8564 - val_loss: 4.3561 - val_gender_output_loss: 0.8358 - val_image_quality_output_loss: 0.5702 - val_age_output_loss: 0.4551 - val_weight_output_loss: 0.4179 - val_bag_output_loss: 0.5454 - val_footwear_output_loss: 0.6017 - val_pose_output_loss: 0.5417 - val_emotion_output_loss: 0.3885 - val_gender_output_acc: 0.5766 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.7999 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7056 - val_footwear_output_acc: 0.6813 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
# Epoch 49/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.5963 - gender_output_loss: 0.2391 - image_quality_output_loss: 0.5762 - age_output_loss: 0.4511 - weight_output_loss: 0.4191 - bag_output_loss: 0.5081 - footwear_output_loss: 0.4841 - pose_output_loss: 0.5359 - emotion_output_loss: 0.3825 - gender_output_acc: 0.8826 - image_quality_output_acc: 0.7007 - age_output_acc: 0.8000 - weight_output_acc: 0.8166 - bag_output_acc: 0.7477 - footwear_output_acc: 0.7618 - pose_output_acc: 0.7441 - emotion_output_acc: 0.8564 - val_loss: 4.3451 - val_gender_output_loss: 0.8238 - val_image_quality_output_loss: 0.5709 - val_age_output_loss: 0.4531 - val_weight_output_loss: 0.4176 - val_bag_output_loss: 0.5408 - val_footwear_output_loss: 0.6045 - val_pose_output_loss: 0.5463 - val_emotion_output_loss: 0.3880 - val_gender_output_acc: 0.6986 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7061 - val_footwear_output_acc: 0.6932 - val_pose_output_acc: 0.7461 - val_emotion_output_acc: 0.8531
# Epoch 50/50
# 360/360 [==============================] - 91s 252ms/step - loss: 3.5287 - gender_output_loss: 0.1935 - image_quality_output_loss: 0.5767 - age_output_loss: 0.4515 - weight_output_loss: 0.4195 - bag_output_loss: 0.5043 - footwear_output_loss: 0.4662 - pose_output_loss: 0.5341 - emotion_output_loss: 0.3830 - gender_output_acc: 0.9030 - image_quality_output_acc: 0.7010 - age_output_acc: 0.8000 - weight_output_acc: 0.8168 - bag_output_acc: 0.7496 - footwear_output_acc: 0.7727 - pose_output_acc: 0.7454 - emotion_output_acc: 0.8566 - val_loss: 4.4282 - val_gender_output_loss: 0.9105 - val_image_quality_output_loss: 0.5714 - val_age_output_loss: 0.4534 - val_weight_output_loss: 0.4185 - val_bag_output_loss: 0.5410 - val_footwear_output_loss: 0.5964 - val_pose_output_loss: 0.5483 - val_emotion_output_loss: 0.3888 - val_gender_output_acc: 0.7117 - val_image_quality_output_acc: 0.7107 - val_age_output_acc: 0.8000 - val_weight_output_acc: 0.8223 - val_bag_output_acc: 0.7073 - val_footwear_output_acc: 0.7075 - val_pose_output_acc: 0.7463 - val_emotion_output_acc: 0.8531
#
# 360/360 [==============================]

# %%
model
